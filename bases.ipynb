# %% [markdown]
# # Les bases de **Python**

# %% [markdown]
# ### 1 - Utiliser Python comme une calculatrice

# %%
4+5

# %%
3+2*4

# %%
2**3

# %%
5/2

# %%
5//2

# %%
5%2

# %% [markdown]
# ### 2 - Avec des nombres complexes

# %%
cplx = 4+3j

# %%
cplx

# %%
cplx.real

# %%
cplx.imag

# %%
abs(cplx)

# %% [markdown]
# ### 3 - Bibliothèque **math**

# %%
cos(0)

# %%
import math
cos(0)

# %%
cos(pi)

# %%
import math 
help(math)

# %% [markdown]
# Indiquer le code permettant de calculer a = exponentielle(racine(2))

# %%
a =

# %% [markdown]
# Indiquer le code permettant de calculer b = j^2

# %%
b =

# %% [markdown]
# ### 4 - Chaînes de caractères

# %%
chaine = 'Bonjour MRIT'

# %%
chaine[0]

# %%
chaine[3]

# %%
chaine[-1]

# %%
chaine[-2]

# %%
len(chaine)

# %%
chaine + chaine

# %%
4 * chaine

# %% [markdown]
# ### 5 - Types de variables

# %%
a = 2
type (a)

# %%
b = a/3
type(b)

# %%
c = (a==b)
c

# %%
type(c)

# %%
cplx = 4+3j
type(cplx)

# %%
chaine = 'Bonjour MRIT'
type(chaine)
